# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataframe = pd.read_csv("Salary_dataset.csv")
X = dataframe.iloc[:, 1].values
Y = dataframe.iloc[:, 2].values

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4)

plt.scatter(X_train, Y_train, marker='o')
plt.show() #visualize dataset

# %%
reg = LinearRegression()
reg.fit(X_train.reshape(-1, 1),Y_train.reshape(-1,1))

accuracy = reg.score(X_test.reshape(-1, 1), Y_test.reshape(-1, 1))
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9627634435544555

# %%
dataframe = pd.read_csv("USA_Housing.csv")
X = dataframe.iloc[:, :5].values
y = dataframe.iloc[:, 5].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.6, random_state=42)

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)

accuracy = reg.score(X_test, y_test)
print("Accuracy: ", accuracy)
# Out:
# Accuracy:  0.9148695870890442
